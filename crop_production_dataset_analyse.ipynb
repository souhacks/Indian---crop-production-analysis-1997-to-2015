# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

matplotlib.rcParams['font.size'] = 14
matplotlib.rcParams['figure.figsize'] = (9, 5)
matplotlib.rcParams['figure.facecolor'] = '#00000000'

# %%
df = pd.read_csv('crop_production.csv')
df.head()
# Out:
#                     State_Name District_Name  Crop_Year       Season  \
# 0  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 1  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 2  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 3  Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 4  Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
#
#                   Crop    Area  Production
# 0             Arecanut  1254.0      2000.0
# 1  Other Kharif pulses     2.0         1.0
# 2                 Rice   102.0       321.0
# 3               Banana   176.0       641.0
# 4            Cashewnut   720.0       165.0

# %%
print(df.shape)
print("the numbers of rows are", df.shape[0])
print("the numbers of columns are", df.shape[1])
# Out:
# (246091, 7)
# the numbers of rows are 246091
# the numbers of columns are 7

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246091 entries, 0 to 246090
# Data columns (total 7 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   State_Name     246091 non-null  object
#  1   District_Name  246091 non-null  object
#  2   Crop_Year      246091 non-null  int64
#  3   Season         246091 non-null  object
#  4   Crop           246091 non-null  object
#  5   Area           246091 non-null  float64
#  6   Production     242361 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.1+ MB

# %%
df.isna().sum()
# Out:
# State_Name          0
# District_Name       0
# Crop_Year           0
# Season              0
# Crop                0
# Area                0
# Production       3730
# dtype: int64

# %%
sns.heatmap(df.isna(), cmap='coolwarm', cbar=False)
# Out:
# <AxesSubplot:>

# %%
df['Production'].fillna(0, inplace=True)

# %%
df['Production'].isna().sum()
# Out:
# 0

# %%
df.columns
# Out:
# Index(['State_Name', 'District_Name', 'Crop_Year', 'Season', 'Crop', 'Area',
#        'Production'],
#       dtype='object')

# %%
print(df.State_Name.unique())
print('The number of States and Union Terriorties are : ',df.State_Name.nunique())
# Out:
# ['Andaman and Nicobar Islands' 'Andhra Pradesh' 'Arunachal Pradesh'
#  'Assam' 'Bihar' 'Chandigarh' 'Chhattisgarh' 'Dadra and Nagar Haveli'
#  'Goa' 'Gujarat' 'Haryana' 'Himachal Pradesh' 'Jammu and Kashmir '
#  'Jharkhand' 'Karnataka' 'Kerala' 'Madhya Pradesh' 'Maharashtra' 'Manipur'
#  'Meghalaya' 'Mizoram' 'Nagaland' 'Odisha' 'Puducherry' 'Punjab'
#  'Rajasthan' 'Sikkim' 'Tamil Nadu' 'Telangana ' 'Tripura' 'Uttar Pradesh'
#  'Uttarakhand' 'West Bengal']
# The number of States and Union Terriorties are :  33

# %%
df.State_Name.value_counts()
# Out:
# State_Name
# Uttar Pradesh                  33306
# Madhya Pradesh                 22943
# Karnataka                      21122
# Bihar                          18885
# Assam                          14628
# Odisha                         13575
# Tamil Nadu                     13547
# Maharashtra                    12628
# Rajasthan                      12514
# Chhattisgarh                   10709
# Andhra Pradesh                  9628
# West Bengal                     9613
# Gujarat                         8436
# Haryana                         5875
# Telangana                       5649
# Uttarakhand                     4896
# Kerala                          4261
# Nagaland                        3906
# Punjab                          3173
# Meghalaya                       2867
# Arunachal Pradesh               2546
# Himachal Pradesh                2494
# Jammu and Kashmir               1634
# Tripura                         1412
# Manipur                         1267
# ...

# %% [markdown]
# Above show that top agriculture rich states like Uttar Pradesh, Madhya Pradesh and Karnataka than other states.

# %%
print(df.District_Name.unique())
print('The numbers of districts are : ', df.District_Name.nunique())
# Out:
# ['NICOBARS' 'NORTH AND MIDDLE ANDAMAN' 'SOUTH ANDAMANS' 'ANANTAPUR'
#  'CHITTOOR' 'EAST GODAVARI' 'GUNTUR' 'KADAPA' 'KRISHNA' 'KURNOOL'
#  'PRAKASAM' 'SPSR NELLORE' 'SRIKAKULAM' 'VISAKHAPATANAM' 'VIZIANAGARAM'
#  'WEST GODAVARI' 'ANJAW' 'CHANGLANG' 'DIBANG VALLEY' 'EAST KAMENG'
#  'EAST SIANG' 'KURUNG KUMEY' 'LOHIT' 'LONGDING' 'LOWER DIBANG VALLEY'
#  'LOWER SUBANSIRI' 'NAMSAI' 'PAPUM PARE' 'TAWANG' 'TIRAP' 'UPPER SIANG'
#  'UPPER SUBANSIRI' 'WEST KAMENG' 'WEST SIANG' 'BAKSA' 'BARPETA'
#  'BONGAIGAON' 'CACHAR' 'CHIRANG' 'DARRANG' 'DHEMAJI' 'DHUBRI' 'DIBRUGARH'
#  'DIMA HASAO' 'GOALPARA' 'GOLAGHAT' 'HAILAKANDI' 'JORHAT' 'KAMRUP'
#  'KAMRUP METRO' 'KARBI ANGLONG' 'KARIMGANJ' 'KOKRAJHAR' 'LAKHIMPUR'
#  'MARIGAON' 'NAGAON' 'NALBARI' 'SIVASAGAR' 'SONITPUR' 'TINSUKIA'
#  'UDALGURI' 'ARARIA' 'ARWAL' 'AURANGABAD' 'BANKA' 'BEGUSARAI' 'BHAGALPUR'
#  'BHOJPUR' 'BUXAR' 'DARBHANGA' 'GAYA' 'GOPALGANJ' 'JAMUI' 'JEHANABAD'
#  'KAIMUR (BHABUA)' 'KATIHAR' 'KHAGARIA' 'KISHANGANJ' 'LAKHISARAI'
# ...

# %%
df.District_Name.value_counts()
# Out:
# District_Name
# BIJAPUR      945
# TUMKUR       936
# BELGAUM      925
# HASSAN       895
# BELLARY      887
#             ...
# HYDERABAD      8
# KHUNTI         6
# RAMGARH        6
# NAMSAI         1
# MUMBAI         1
# Name: count, Length: 646, dtype: int64

# %% [markdown]
# On District front, we come conclude that more data coming from Bijapur, Tumkur and Belgaum than other districts

# %%
print("Total numbers of Years in the dataset : ",df.Crop_Year.nunique())
print("Minimum year number present in dataset is ",df.Crop_Year.min())
print("Maximum year number present in dataset is ",df.Crop_Year.max())
print(df.Crop_Year.unique())
# Out:
# Total numbers of Years in the dataset :  19
# Minimum year number present in dataset is  1997
# Maximum year number present in dataset is  2015
# [2000 2001 2002 2003 2004 2005 2006 2010 1997 1998 1999 2007 2008 2009
#  2011 2012 2013 2014 2015]

# %%
df.Crop_Year.value_counts()
# Out:
# Crop_Year
# 2003    17287
# 2002    16671
# 2008    14550
# 2007    14526
# 2006    14328
# 2004    14117
# 2009    14116
# 2011    14071
# 2010    14065
# 2005    13799
# 2000    13658
# 2013    13650
# 2012    13410
# 2001    13361
# 1999    12515
# 1998    11533
# 2014    10973
# 1997     8899
# 2015      562
# Name: count, dtype: int64

# %% [markdown]
# Year 2003 providing more data than other years

# %%
print('Numbers of seasons in dataset', df.Season.nunique())
print('Names of seasons are: ',df.Season.unique())
print('Value_counts of seasons are')
print(df.Season.value_counts())
# Out:
# Numbers of seasons in dataset 6
# Names of seasons are:  ['Kharif     ' 'Whole Year ' 'Autumn     ' 'Rabi       ' 'Summer     '
#  'Winter     ']
# Value_counts of seasons are
# Season
# Kharif         95951
# Rabi           66987
# Whole Year     57305
# Summer         14841
# Winter          6058
# Autumn          4949
# Name: count, dtype: int64

# %% [markdown]
# The Kharif cropping seabon is from July-October during the south-west monsoon and the Rabi cropping season is from October-March(Winter).
# The crops grown between March and June are summer crops. Crops in India are dependent on Monsoon water. There will be variation in crop production from one yera to another.

# %%
print('Numbers of crop varieties in dataset', df.Crop.nunique())
print('Names of crop varieties are: ',df.Crop.unique())
print('Top 10 Value_counts of crop varieties are')
print(df.Crop.value_counts().head(10))
# Out:
# Numbers of crop varieties in dataset 124
# Names of crop varieties are:  ['Arecanut' 'Other Kharif pulses' 'Rice' 'Banana' 'Cashewnut' 'Coconut '
#  'Dry ginger' 'Sugarcane' 'Sweet potato' 'Tapioca' 'Black pepper'
#  'Dry chillies' 'other oilseeds' 'Turmeric' 'Maize' 'Moong(Green Gram)'
#  'Urad' 'Arhar/Tur' 'Groundnut' 'Sunflower' 'Bajra' 'Castor seed'
#  'Cotton(lint)' 'Horse-gram' 'Jowar' 'Korra' 'Ragi' 'Tobacco' 'Gram'
#  'Wheat' 'Masoor' 'Sesamum' 'Linseed' 'Safflower' 'Onion'
#  'other misc. pulses' 'Samai' 'Small millets' 'Coriander' 'Potato'
#  'Other  Rabi pulses' 'Soyabean' 'Beans & Mutter(Vegetable)' 'Bhindi'
#  'Brinjal' 'Citrus Fruit' 'Cucumber' 'Grapes' 'Mango' 'Orange'
#  'other fibres' 'Other Fresh Fruits' 'Other Vegetables' 'Papaya'
#  'Pome Fruit' 'Tomato' 'Rapeseed &Mustard' 'Mesta' 'Cowpea(Lobia)' 'Lemon'
#  'Pome Granet' 'Sapota' 'Cabbage' 'Peas  (vegetable)' 'Niger seed'
#  'Bottle Gourd' 'Sannhamp' 'Varagu' 'Garlic' 'Ginger' 'Oilseeds total'
# ...

# %%
df['Production'].describe()
# Out:
# count    2.460910e+05
# mean     5.736744e+05
# std      1.693614e+07
# min      0.000000e+00
# 25%      7.700000e+01
# 50%      6.910000e+02
# 75%      6.769000e+03
# max      1.250800e+09
# Name: Production, dtype: float64

# %%
print("Max value in the production is:", df['Production'].max())
# Out:
# Max value in the production is: 1250800000.0

# %%
df['Production'].value_counts(ascending=False)
# Out:
# Production
# 0.000000e+00    7253
# 1.000000e+00    4028
# 1.000000e+02    3521
# 2.000000e+00    2964
# 3.000000e+00    2311
#                 ...
# 2.120000e+08       1
# 1.070000e+00       1
# 2.293410e+05       1
# 1.870600e+04       1
# 5.978990e+05       1
# Name: count, Length: 51627, dtype: int64

# %%
plt.boxplot(df['Production'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x23199d32d00>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2319bf582e0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x23199d32a30>],
#  'medians': [<matplotlib.lines.Line2D at 0x2319bf58880>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2319bf58b50>],
#  'means': []}

# %%
plt.boxplot(df['Area'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2319bfc55b0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2319bfc5b50>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2319bfc52e0>],
#  'medians': [<matplotlib.lines.Line2D at 0x2319bfd1130>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2319bfd1400>],
#  'means': []}

# %%
Produce = df.groupby('State_Name')['Production'].sum().reset_index().sort_values('Production', ascending=False).head(5)
Produce
# Out:
#         State_Name    Production
# 15          Kerala  9.788005e+10
# 1   Andhra Pradesh  1.732459e+10
# 27      Tamil Nadu  1.207644e+10
# 30   Uttar Pradesh  3.234493e+09
# 3            Assam  2.111752e+09

# %% [markdown]
# Kerala is top state with respect to the Production.

# %%
plt.figure(figsize=(15,15))
sns.barplot(x='Production', y='State_Name', orient='h', data = df, ci=None)
# Out:
# C:\Users\hh\AppData\Local\Temp\ipykernel_22344\3963818893.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='Production', y='State_Name', orient='h', data = df, ci=None)
# C:\Users\hh\AppData\Roaming\Python\Python39\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\hh\AppData\Roaming\Python\Python39\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %% [markdown]
# ## EDA:

# %%
df.head()
# Out:
#                     State_Name District_Name  Crop_Year       Season  \
# 0  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 1  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 2  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 3  Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 4  Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
#
#                   Crop    Area  Production
# 0             Arecanut  1254.0      2000.0
# 1  Other Kharif pulses     2.0         1.0
# 2                 Rice   102.0       321.0
# 3               Banana   176.0       641.0
# 4            Cashewnut   720.0       165.0

# %%
df.describe()
# Out:
#            Crop_Year          Area    Production
# count  246091.000000  2.460910e+05  2.460910e+05
# mean     2005.643018  1.200282e+04  5.736744e+05
# std         4.952164  5.052340e+04  1.693614e+07
# min      1997.000000  4.000000e-02  0.000000e+00
# 25%      2002.000000  8.000000e+01  7.700000e+01
# 50%      2006.000000  5.820000e+02  6.910000e+02
# 75%      2010.000000  4.392000e+03  6.769000e+03
# max      2015.000000  8.580100e+06  1.250800e+09

# %%
plt.hist(df['Area'], bins = 5)
# Out:
# (array([2.46077e+05, 6.00000e+00, 5.00000e+00, 2.00000e+00, 1.00000e+00]),
#  array([4.00000000e-02, 1.71602003e+06, 3.43204002e+06, 5.14806002e+06,
#         6.86408001e+06, 8.58010000e+06]),
#  <BarContainer object of 5 artists>)

# %%
plt.hist(df['Production'], bins = 2)
# Out:
# (array([2.46034e+05, 5.70000e+01]),
#  array([0.0000e+00, 6.2540e+08, 1.2508e+09]),
#  <BarContainer object of 2 artists>)

# %% [markdown]
# Differnet zones columns get introduced in order to make our dataset more clear and easy to understandable.

# %% [markdown]
# Seven zones are-
# north_india
# south_india
# west_india
# east_india
# central_india
# north_east_india
# ut_india

# %%
# zone - wise production - 1997-2014
north_india = ['Jammu and Kashmir', 'Punjab', 'Himachal Pradesh', 'Haryana', 'Uttarakhand', 'Uttar Pradesh', 'Chandigarh']
east_india = ['Bihar', 'Odisha', 'Jharkhand', 'West Bengal']
south_india = ['Andhra Pradesh', 'Karnataka', 'Kerala' ,'Tamil Nadu', 'Telangana']
west_india = ['Rajasthan' , 'Gujarat', 'Goa','Maharashtra']
central_india = ['Madhya Pradesh', 'Chhattisgarh']
north_east_india = ['Assam', 'Sikkim', 'Nagaland', 'Meghalaya', 'Manipur', 'Mizoram', 'Tripura', 'Arunachal Pradesh']
ut_india = ['Andaman and Nicobar Islands', 'Dadra and Nagar Haveli', 'Puducherry']

# %%
def get_zonal_names(row):
    if row['State_Name'].strip() in north_india:
        val = 'North_zone'
    elif row['State_Name'].strip() in south_india:
        val = 'South_zone'
    elif row['State_Name'].strip() in east_india:
        val = 'East_zone'    
    elif row['State_Name'].strip() in west_india:
        val = 'West_zone'
    elif row['State_Name'].strip() in central_india:
        val = 'Central_zone'
    elif row['State_Name'].strip() in north_east_india:
        val = 'NE_zone'
    elif row['State_Name'].strip() in ut_india:
        val = 'Union Terr'
    else:
        val = 'No val'
    return val
df['Zones'] = df.apply(get_zonal_names, axis = 1)
df['Zones'].unique()
# Out:
# array(['Union Terr', 'South_zone', 'NE_zone', 'East_zone', 'North_zone',
#        'Central_zone', 'West_zone'], dtype=object)

# %%
df['Zones'].value_counts()
# Out:
# Zones
# South_zone      54207
# North_zone      51468
# East_zone       43339
# West_zone       33786
# Central_zone    33652
# NE_zone         28297
# Union Terr       1342
# Name: count, dtype: int64

# %% [markdown]
# Here we can see that top zones are South_zone and North_zone

# %% [markdown]
# Different caterories (Cereal, Pulses,Fruits,Beans,Vegetables, Spices, fibres, Nuts, Natural Polymer,Coffee, Tea,
#                       Total foodgrain, Pulses, Oilseeds, Paddy, Commercial, Sugarcane, forage plants and Others)

# %%
crop=df['Crop']
def cat_crop(crop):
    for i in ['Rice','Maize','Wheat','Barley','Varagu','Other Cereals & Millets','Ragi','Small millets','Bajra','Jowar', 'Paddy','Total foodgrain','Jobster']:
        if crop==i:
            return 'Cereal'
    for i in ['Moong','Urad','Arhar/Tur','Peas & beans','Masoor',
              'Other Kharif pulses','other misc. pulses','Ricebean (nagadal)',
              'Rajmash Kholar','Lentil','Samai','Blackgram','Korra','Cowpea(Lobia)',
              'Other  Rabi pulses','Other Kharif pulses','Peas & beans (Pulses)','Pulses total','Gram']:
        if crop==i:
            return 'Pulses'
    for i in ['Peach','Apple','Litchi','Pear','Plums','Ber','Sapota','Lemon','Pome Granet',
               'Other Citrus Fruit','Water Melon','Jack Fruit','Grapes','Pineapple','Orange',
               'Pome Fruit','Citrus Fruit','Other Fresh Fruits','Mango','Papaya','Coconut','Banana']:
        if crop==i:
            return 'Fruits'
    for i in ['Bean','Lab-Lab','Moth','Guar seed','Soyabean','Horse-gram']:
        if crop==i:
            return 'Beans'
    for i in ['Turnip','Peas','Beet Root','Carrot','Yam','Ribed Guard','Ash Gourd ','Pump Kin','Redish','Snak Guard','Bottle Gourd',
              'Bitter Gourd','Cucumber','Drum Stick','Cauliflower','Beans & Mutter(Vegetable)','Cabbage',
              'Bhindi','Tomato','Brinjal','Khesari','Sweet potato','Potato','Onion','Tapioca','Colocosia']:
              if crop==i:
                return 'Vegetables'
    for i in ['Perilla','Ginger','Cardamom','Black pepper','Dry ginger','Garlic','Coriander','Turmeric','Dry chillies','Cond-spcs other']:
        if crop==i:
            return 'spices'
    for i in ['other fibres','Kapas','Jute & mesta','Jute','Mesta','Cotton(lint)','Sannhamp']:
        if crop==i:
            return 'fibres'
    for i in ['Arcanut (Processed)','Atcanut (Raw)','Cashewnut Processed','Cashewnut Raw','Cashewnut','Arecanut','Groundnut']:
        if crop==i:
            return 'Nuts'
    for i in ['other oilseeds','Safflower','Niger seed','Castor seed','Linseed','Sunflower','Rapeseed &Mustard','Sesamum','Oilseeds total']:
        if crop==i:
            return 'oilseeds'
    for i in ['Tobacco','Coffee','Tea','Sugarcane','Rubber']:
        if crop==i:
            return 'Commercial'

df['cat_crop']=df['Crop'].apply(cat_crop)

# %%
df['cat_crop'].value_counts()
# Out:
# cat_crop
# Cereal        63800
# Pulses        41689
# oilseeds      34454
# Vegetables    23325
# spices        21986
# Nuts          11588
# Commercial    10716
# fibres        10195
# Beans          9355
# Fruits         6243
# Name: count, dtype: int64

# %% [markdown]
# Top frequency of crop types are Cereal, Pulses and oilseeds

# %% [markdown]
# # VISUALIZATION

# %%
df.head()
# Out:
#                     State_Name District_Name  Crop_Year       Season  \
# 0  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 1  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 2  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 3  Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 4  Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
#
#                   Crop    Area  Production       Zones cat_crop
# 0             Arecanut  1254.0      2000.0  Union Terr     Nuts
# 1  Other Kharif pulses     2.0         1.0  Union Terr   Pulses
# 2                 Rice   102.0       321.0  Union Terr   Cereal
# 3               Banana   176.0       641.0  Union Terr   Fruits
# 4            Cashewnut   720.0       165.0  Union Terr     Nuts

# %%
fig, ax = plt.subplots(figsize=(20,10))
sns.barplot(x='Zones', y='Production', data = df, ci=None)
plt.yscale('log')
plt.title('Zone-wise Production')
# Out:
# C:\Users\hh\AppData\Local\Temp\ipykernel_22344\455626737.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='Zones', y='Production', data = df, ci=None)
# C:\Users\hh\AppData\Roaming\Python\Python39\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\hh\AppData\Roaming\Python\Python39\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\hh\AppData\Roaming\Python\Python39\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# ...

# %% [markdown]
# Production wise top zone is South Zone

# %%
# Let's find out in south zone which state have more production:
south_zone = df[(df['Zones']=='South_zone')]
sns.set_style('darkgrid')
sns.barplot(x='State_Name', y='Production', data = south_zone, ci=None)
plt.yscale('log')
plt.title('Southern_Zone Production')
# Out:
# C:\Users\hh\AppData\Local\Temp\ipykernel_22344\2777322340.py:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='State_Name', y='Production', data = south_zone, ci=None)
# C:\Users\hh\AppData\Roaming\Python\Python39\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\hh\AppData\Roaming\Python\Python39\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %% [markdown]
# Top South Indian states are Kerala, Andhra Pradseh and Tamil Nadu.

# %%
north_zone = df[(df['Zones'])=='North_zone']
fig, ax = plt.subplots(figsize=(15,10))
sns.barplot(x='State_Name', y='Production', data=north_zone, ci=None)
plt.yscale('log')
plt.xticks(rotation=90)
plt.title('Northern-Zone Production')
# Out:
# C:\Users\hh\AppData\Local\Temp\ipykernel_22344\3655472672.py:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='State_Name', y='Production', data=north_zone, ci=None)
# C:\Users\hh\AppData\Roaming\Python\Python39\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\hh\AppData\Roaming\Python\Python39\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %% [markdown]
# # SEASON vs PRODUCTION

# %%
df_season = df.copy()
season = df.groupby(by='Season')['Production'].sum().reset_index().sort_values('Production', ascending=False)
season
# Out:
#         Season    Production
# 4  Whole Year   1.344248e+11
# 1  Kharif       4.029970e+09
# 2  Rabi         2.051688e+09
# 5  Winter       4.345498e+08
# 3  Summer       1.706579e+08
# 0  Autumn       6.441377e+07

# %%
fig, ax = plt.subplots(figsize=(15,10))
sns.barplot(x='Season', y ='Production', data = season, ci=None)
plt.yscale('log')
plt.title('Seasonal Crops vs Production')
# Out:
# C:\Users\hh\AppData\Local\Temp\ipykernel_22344\1061204921.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='Season', y ='Production', data = season, ci=None)
# C:\Users\hh\AppData\Roaming\Python\Python39\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\hh\AppData\Roaming\Python\Python39\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %% [markdown]
# Top crop categories which shows high production values are Whole Year, Kharif and Rabi crops.

# %%
crop_produce = df.groupby(by='Crop')['Production'].sum().reset_index().sort_values(by='Production', ascending=False).head(10)
crop_produce
# Out:
#              Crop    Production
# 28       Coconut   1.299816e+11
# 106     Sugarcane  5.535682e+09
# 95           Rice  1.605470e+09
# 119         Wheat  1.332826e+09
# 87         Potato  4.248263e+08
# 33   Cotton(lint)  2.970000e+08
# 59          Maize  2.733418e+08
# 49           Jute  1.815582e+08
# 7          Banana  1.461327e+08
# 105      Soyabean  1.418372e+08

# %%
plt.figure(figsize=(20,5))
sns.barplot(x='Crop', y='Production', data = crop_produce, ci=None)
plt.yscale('log')
plt.title('Overall crops vs Production')
# Out:
# C:\Users\hh\AppData\Local\Temp\ipykernel_22344\908446420.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='Crop', y='Production', data = crop_produce, ci=None)
# C:\Users\hh\AppData\Roaming\Python\Python39\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\hh\AppData\Roaming\Python\Python39\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %% [markdown]
# Coconut, Sugarcane and Rice are the crop production wise

# %%
year_prod = df.groupby(by='Crop_Year')['Production'].sum().reset_index()
year_prod
# Out:
#     Crop_Year    Production
# 0        1997  8.512329e+08
# 1        1998  5.825321e+09
# 2        1999  6.434666e+09
# 3        2000  7.449709e+09
# 4        2001  7.465541e+09
# 5        2002  7.696955e+09
# 6        2003  7.917974e+09
# 7        2004  8.189462e+09
# 8        2005  8.043757e+09
# 9        2006  8.681913e+09
# 10       2007  6.879442e+09
# 11       2008  7.717018e+09
# 12       2009  7.660494e+09
# 13       2010  6.307609e+09
# 14       2011  1.430890e+10
# 15       2012  8.171055e+09
# 16       2013  1.290359e+10
# 17       2014  8.664541e+09
# 18       2015  6.935065e+06

# %%
plt.figure(figsize=(15,5))
plt.bar(year_prod['Crop_Year'],year_prod['Production'])
plt.xlabel('Year')
plt.ylabel('Production Count')
plt.title('Yearwise Production Status')
# Out:
# Text(0.5, 1.0, 'Yearwise Production Status')

# %%
# Crop-category wise production:
cat_prod = df.groupby(by='cat_crop')['Production'].sum().reset_index()
cat_prod
# Out:
#      cat_crop    Production
# 0       Beans  1.624564e+08
# 1      Cereal  3.594987e+09
# 2  Commercial  5.547619e+09
# 3      Fruits  1.717526e+08
# 4        Nuts  1.359093e+08
# 5      Pulses  2.084907e+08
# 6  Vegetables  6.230645e+08
# 7      fibres  4.914495e+08
# 8    oilseeds  1.864416e+08
# 9      spices  5.305029e+07

# %%
plt.figure(figsize=(16,8))
sns.barplot(x='cat_crop', y='Production', data=cat_prod)
plt.yscale('log')
plt.title('Production vs Category of Crops')
# Out:
# C:\Users\hh\AppData\Roaming\Python\Python39\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\hh\AppData\Roaming\Python\Python39\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\hh\AppData\Roaming\Python\Python39\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# Text(0.5, 1.0, 'Production vs Category of Crops')

# %%
# State versus Crop Category versus Season plot:
plt.figure(figsize=(20,8))
sns.scatterplot(x='State_Name', y='cat_crop', hue='Season', data=df)
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\hh\AppData\Roaming\Python\Python39\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\hh\AppData\Roaming\Python\Python39\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\hh\AppData\Roaming\Python\Python39\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %% [markdown]
# South zone: Top producing state Kerala shows a abundance of whole year seasonal crops.
# North zone: Top producing state Punjab shows abundance of Kharif, Rabi and Whole year crops

# %%
# Different propogation of crop categories for india:
df1 = df['cat_crop'].value_counts()
df1.plot(radius=3, kind='pie', autopct='%1.1f', pctdistance=0.6)
plt.tick_params(labelsize=10)

# %% [markdown]
# # Which State domainates in crop production with different categories of crops?

# %%
df2 = pd.crosstab(df['State_Name'], df['cat_crop'])

# %%
df2
# Out:
# cat_crop                     Beans  Cereal  Commercial  Fruits  Nuts  Pulses  \
# State_Name
# Andaman and Nicobar Islands      0      20          15      16    38       9
# Andhra Pradesh                 391    2271         475     502   675    1344
# Arunachal Pradesh               26    1021         168       0    26      67
# Assam                            0    2952         856     920   400    2235
# Bihar                          280    6110         756     226   130    3735
# Chandigarh                       0      39           0       0     0      15
# Chhattisgarh                   663    1824         328     269   264    2163
# Dadra and Nagar Haveli           0     116          12       9     9      64
# Goa                              0      62          22      16    48      32
# Gujarat                        420    2490         373     157   685    1536
# Haryana                        163    1712         309      52   174    1208
# ...

# %%
df2.plot(kind='bar', stacked=True, figsize=(16,8))
# Out:
# <AxesSubplot:xlabel='State_Name'>

# %% [markdown]
# Uttar Pradesh have more crop categories than any other Indian State.

# %% [markdown]
# # Which crop is seen in high frequency and when and where is it grown in Indian?

# %%
crop_name = df['Crop'].value_counts().head(5)
crop_name
# Out:
# Crop
# Rice                 15104
# Maize                13947
# Moong(Green Gram)    10318
# Urad                  9850
# Sesamum               9046
# Name: count, dtype: int64

# %%
rice_df = df[df['Crop']=='Rice']
print(rice_df.shape)
rice_df.head(5)
# Out:
# (15104, 9)
#                      State_Name District_Name  Crop_Year       Season  Crop  \
# 2   Andaman and Nicobar Islands      NICOBARS       2000  Kharif       Rice
# 12  Andaman and Nicobar Islands      NICOBARS       2001  Kharif       Rice
# 18  Andaman and Nicobar Islands      NICOBARS       2002  Kharif       Rice
# 27  Andaman and Nicobar Islands      NICOBARS       2003  Kharif       Rice
# 36  Andaman and Nicobar Islands      NICOBARS       2004  Kharif       Rice
#
#       Area  Production       Zones cat_crop
# 2   102.00      321.00  Union Terr   Cereal
# 12   83.00      300.00  Union Terr   Cereal
# 18  189.20      510.84  Union Terr   Cereal
# 27   52.00       90.17  Union Terr   Cereal
# 36   52.94       72.57  Union Terr   Cereal

# %%
sns.barplot(x='Season', y='Production', data=rice_df, ci=None)
# Out:
# C:\Users\hh\AppData\Local\Temp\ipykernel_22344\2692255646.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='Season', y='Production', data=rice_df, ci=None)
# C:\Users\hh\AppData\Roaming\Python\Python39\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\hh\AppData\Roaming\Python\Python39\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
plt.figure(figsize=(20,8))
sns.barplot(x='State_Name', y='Production', ci=None, data=rice_df)
plt.xticks(rotation=90)
plt.title('Rice production with respect to State Name')
# Out:
# C:\Users\hh\AppData\Local\Temp\ipykernel_22344\644922342.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='State_Name', y='Production', ci=None, data=rice_df)
# C:\Users\hh\AppData\Roaming\Python\Python39\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\hh\AppData\Roaming\Python\Python39\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
top_rice_prod = df.groupby(by='District_Name')['Production'].sum().reset_index().sort_values(by='Production', ascending=False).head(10)
top_rice_prod
# Out:
#           District_Name    Production
# 334           KOZHIKODE  1.528074e+10
# 372          MALAPPURAM  1.451840e+10
# 587  THIRUVANANTHAPURAM  1.002271e+10
# 590            THRISSUR  9.923508e+09
# 286              KANNUR  9.783432e+09
# 172       EAST GODAVARI  8.271057e+09
# 298           KASARAGOD  7.732217e+09
# 326              KOLLAM  7.151945e+09
# 437            PALAKKAD  6.369382e+09
# 178           ERNAKULAM  5.021649e+09

# %%
sum_max = top_rice_prod['Production'].sum()
print(sum_max)
# Out:
# 94075046785.42001

# %%
plt.figure(figsize=(18,12))
sns.barplot(x='District_Name', y='Production', data=top_rice_prod, ci=None)
plt.xticks(rotation=90)
plt.title('Production of rice with respect to District-wise')
# Out:
# C:\Users\hh\AppData\Local\Temp\ipykernel_22344\2950703304.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='District_Name', y='Production', data=top_rice_prod, ci=None)
# C:\Users\hh\AppData\Roaming\Python\Python39\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\hh\AppData\Roaming\Python\Python39\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
plt.figure(figsize=(15,10))
sns.barplot(x='Crop_Year', y='Production', data=rice_df, ci=None)
plt.xticks(rotation=45)
plt.title('Rice production w.r.t Crop Year')
# Out:
# C:\Users\hh\AppData\Local\Temp\ipykernel_22344\3918692383.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='Crop_Year', y='Production', data=rice_df, ci=None)
# C:\Users\hh\AppData\Roaming\Python\Python39\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\hh\AppData\Roaming\Python\Python39\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
sns.jointplot(x='Area', y='Production', data=rice_df, kind='reg')
# Out:
# C:\Users\hh\AppData\Roaming\Python\Python39\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\hh\AppData\Roaming\Python\Python39\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\hh\AppData\Roaming\Python\Python39\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %% [markdown]
# Rice is grown heavily when we look the frequency of crops in India.

# %% [markdown]
# Rice show better grow in winter

# %% [markdown]
# State-wise Punjab dominates in rice-production.

# %% [markdown]
# District wise KOZHIKODE contribute more in rice production

# %% [markdown]
# Year wise 2014 is the year when production reached the maximum.

# %% [markdown]
# Correlation between Area and Production shows high production is directly proportional to Area under cultivation.

# %% [markdown]
# # Which states ranks high in area wise crop production in India?

# %%
df.head()
# Out:
#                     State_Name District_Name  Crop_Year       Season  \
# 0  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 1  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 2  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 3  Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 4  Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
#
#                   Crop    Area  Production       Zones cat_crop
# 0             Arecanut  1254.0      2000.0  Union Terr     Nuts
# 1  Other Kharif pulses     2.0         1.0  Union Terr   Pulses
# 2                 Rice   102.0       321.0  Union Terr   Cereal
# 3               Banana   176.0       641.0  Union Terr   Fruits
# 4            Cashewnut   720.0       165.0  Union Terr     Nuts

# %%
df2 = df.groupby(by='State_Name')['Area'].sum().reset_index().sort_values(by='Area', ascending=False).head(10)
df2
# Out:
#         State_Name          Area
# 30   Uttar Pradesh  4.336316e+08
# 16  Madhya Pradesh  3.298131e+08
# 17     Maharashtra  3.222062e+08
# 25       Rajasthan  2.720249e+08
# 32     West Bengal  2.154052e+08
# 14       Karnataka  2.029101e+08
# 9          Gujarat  1.549440e+08
# 1   Andhra Pradesh  1.315458e+08
# 4            Bihar  1.282720e+08
# 24          Punjab  1.267256e+08

# %%
sns.set_style('darkgrid')
plt.figure(figsize=(25,10))
sns.barplot(x='State_Name', y='Area', data=df2, ci = None)
plt.xticks(rotation=45)
plt.title('Top 10 Agricultural Area in India')
# Out:
# C:\Users\hh\AppData\Local\Temp\ipykernel_22344\755326648.py:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='State_Name', y='Area', data=df2, ci = None)
# C:\Users\hh\AppData\Roaming\Python\Python39\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\hh\AppData\Roaming\Python\Python39\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\hh\AppData\Roaming\Python\Python39\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# ...

# %%
df3 = df.groupby(by='State_Name')['Area'].sum().reset_index().sort_values(by='Area', ascending=False).head(5)
df3

fig, ax = plt.subplots(figsize=(25,30), sharey='col')
count = 1

for state in df3.State_Name.unique():
    plt.subplot(len(df3.State_Name.unique()),1,count)
    sns.lineplot(x=df[df.State_Name==state]['Crop_Year'],y=df[df.State_Name==state]['Production'], ci=None)
    plt.subplots_adjust(hspace=0.6)
    plt.title(state)
    count+=1
# Out:
# C:\Users\hh\AppData\Local\Temp\ipykernel_22344\2878846497.py:9: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(x=df[df.State_Name==state]['Crop_Year'],y=df[df.State_Name==state]['Production'], ci=None)
# C:\Users\hh\AppData\Roaming\Python\Python39\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\hh\AppData\Roaming\Python\Python39\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %% [markdown]
# Top cultivating states based on the Cultivation area is Uttar Pradesh.

# %% [markdown]
# Yearwise Statues of these States:
#
# a. Uttar Pradesh: High Production was seen in 2005 and after that it's been reducing gradually.
#
# b. Madhya Pradesh:1998 showed a high production and then there was gradual reduction but it picked up and 2012 also showed a peak in Production
#
# c. Maharashtra:Production went down drastically in 2006 and again the levels went up and hit a high peak after 2007
#
# d. Rajasthan: the production hit a all time low in the year 2002 and then picked up by 2010
#
# e. West Bengal:the production hit a peak around 2006 but it has hit a low after 2007 and never recovered back.

# %% [markdown]
# # Discuss the top crops grown in Northern parts of India?

# %%
df['Zones'].value_counts()
# Out:
# Zones
# South_zone      54207
# North_zone      51468
# East_zone       43339
# West_zone       33786
# Central_zone    33652
# NE_zone         28297
# Union Terr       1342
# Name: count, dtype: int64

# %%
north_zone = df[(df['Zones']=='North_zone')]
df4=north_zone.groupby(by='State_Name')['Production'].sum().reset_index().sort_values('Production', ascending=False)
df4
# Out:
#            State_Name    Production
# 5       Uttar Pradesh  3.234493e+09
# 4              Punjab  5.863850e+08
# 1             Haryana  3.812739e+08
# 6         Uttarakhand  1.321774e+08
# 2    Himachal Pradesh  1.780517e+07
# 3  Jammu and Kashmir   1.329102e+07
# 0          Chandigarh  6.395650e+04

# %%
plt.figure(figsize=(15,12))
sns.barplot(x='State_Name', y='Production', data=df4, ci=None)
plt.xticks(rotation = 45)
plt.yscale('log')
plt.title('Northern States Production Graph')
# Out:
# C:\Users\hh\AppData\Local\Temp\ipykernel_22344\2224350943.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='State_Name', y='Production', data=df4, ci=None)
# C:\Users\hh\AppData\Roaming\Python\Python39\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\hh\AppData\Roaming\Python\Python39\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
df5=north_zone.groupby(by='Crop')['Production'].sum().reset_index().sort_values('Production', ascending=False).head(10)
print(df5)
plt.figure(figsize=(15,12))
sns.barplot(x='Crop', y='Production', data=df5, ci=None)
plt.xticks(rotation = 45)
plt.yscale('log')
plt.title('Top 10 Crops Production in Northern Zone')
# Out:
#                  Crop    Production
# 46          Sugarcane  2.503517e+09
# 54              Wheat  9.269722e+08
# 41               Rice  4.625489e+08
# 36             Potato  1.998760e+08
# 9        Cotton(lint)  5.455174e+07
# 23              Maize  4.416427e+07
# 1               Bajra  3.807627e+07
# 50    Total foodgrain  3.381309e+07
# 39  Rapeseed &Mustard  2.335103e+07
# 14               Gram  1.295565e+07
# C:\Users\hh\AppData\Local\Temp\ipykernel_22344\2970945158.py:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='Crop', y='Production', data=df5, ci=None)
# C:\Users\hh\AppData\Roaming\Python\Python39\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %% [markdown]
# Production wise top states of North zone are:
# Uttar Pradesh, Punjab and Haryana Or Top crops of these states are:
# Sugarcane, Wheat and Rice

# %% [markdown]
# # Coconut Production Analysis

# %%
df['Crop'].value_counts().head(20)
# Out:
# Crop
# Rice                     15104
# Maize                    13947
# Moong(Green Gram)        10318
# Urad                      9850
# Sesamum                   9046
# Groundnut                 8834
# Sugarcane                 7921
# Wheat                     7899
# Rapeseed &Mustard         7592
# Arhar/Tur                 7578
# Gram                      7361
# Jowar                     7065
# Onion                     7012
# Potato                    6931
# Dry chillies              6489
# Sunflower                 5571
# Bajra                     5427
# Small millets             4652
# Peas & beans (Pulses)     4524
# Cotton(lint)              4518
# Name: count, dtype: int64

# %%
df_coc = df[df['Crop']=='Coconut ']
df_coc
# Out:
#                          State_Name District_Name  Crop_Year       Season  \
# 5       Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 14      Andaman and Nicobar Islands      NICOBARS       2001  Whole Year
# 23      Andaman and Nicobar Islands      NICOBARS       2002  Whole Year
# 32      Andaman and Nicobar Islands      NICOBARS       2003  Whole Year
# 41      Andaman and Nicobar Islands      NICOBARS       2004  Whole Year
# ...                             ...           ...        ...          ...
# 245719                  West Bengal       PURULIA       2004  Whole Year
# 245756                  West Bengal       PURULIA       2005  Whole Year
# 245792                  West Bengal       PURULIA       2006  Whole Year
# 245837                  West Bengal       PURULIA       2007  Whole Year
# 245879                  West Bengal       PURULIA       2008  Whole Year
#
#             Crop      Area  Production       Zones cat_crop
# ...

# %%
sns.barplot(x='Season', y='Production', data=df_coc)
# Out:
# C:\Users\hh\AppData\Roaming\Python\Python39\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\hh\AppData\Roaming\Python\Python39\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\hh\AppData\Roaming\Python\Python39\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <AxesSubplot:xlabel='Season', ylabel='Production'>

# %%
plt.figure(figsize=(15,12))
sns.barplot(x='State_Name', y='Production', data=df_coc, ci=None)
plt.xticks(rotation = 90)
plt.yscale('log')
plt.title('Coconut Production in different States and U.T.')
# Out:
# C:\Users\hh\AppData\Local\Temp\ipykernel_22344\2125267263.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='State_Name', y='Production', data=df_coc, ci=None)
# C:\Users\hh\AppData\Roaming\Python\Python39\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\hh\AppData\Roaming\Python\Python39\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
df_coc_dis = df_coc.groupby(by='District_Name')['Production'].sum().reset_index().sort_values(by='Production', ascending=False).head(5)
df_coc_dis
sum_max = df_coc_dis['Production'].sum()
df_coc_dis['Percent_of_pro'] = df_coc_dis['Production'].apply(lambda x: (x/sum_max)*100)
df_coc_dis
# Out:
#           District_Name    Production  Percent_of_pro
# 80            KOZHIKODE  1.527871e+10       25.676065
# 89           MALAPPURAM  1.451252e+10       24.388474
# 134  THIRUVANANTHAPURAM  1.001337e+10       16.827592
# 136            THRISSUR  9.920739e+09       16.671931
# 66               KANNUR  9.780310e+09       16.435938

# %%
plt.figure(figsize=(15,12))
sns.barplot(x='District_Name', y='Production', data=df_coc_dis, ci=None)
plt.xticks(rotation = 90)
plt.title('Coconut Production w.r.t District')
# Out:
# C:\Users\hh\AppData\Local\Temp\ipykernel_22344\2590996893.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='District_Name', y='Production', data=df_coc_dis, ci=None)
# C:\Users\hh\AppData\Roaming\Python\Python39\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\hh\AppData\Roaming\Python\Python39\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
plt.figure(figsize=(15,12))
sns.barplot(x='Crop_Year', y='Production', data=df_coc, ci=None)
plt.xticks(rotation = 90)
plt.title('Coconut Production Year-wise')
# Out:
# C:\Users\hh\AppData\Local\Temp\ipykernel_22344\1077843326.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='Crop_Year', y='Production', data=df_coc, ci=None)
# C:\Users\hh\AppData\Roaming\Python\Python39\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\hh\AppData\Roaming\Python\Python39\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
sns.jointplot(x='Area', y ='Production', data=df_coc, kind='reg')
# Out:
# C:\Users\hh\AppData\Roaming\Python\Python39\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\hh\AppData\Roaming\Python\Python39\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\hh\AppData\Roaming\Python\Python39\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %% [markdown]
# 1. Coconut cultivation is yearlong and doesn't get restricted to any particular seasons
#
# 2. Top states involved in coconut production are: Kerala, Andhra Pradesh and Tamil Nadu
#
# 3. Top districts featuring in coconut production is KOZHIKODE(11.75%), MALAPPURAM(11.16%) and THIRUVANANTHAPURAM(7.7%)
#
# 4. Yearwise coconut cultivation is strong and its increasing healthly
#
# 5. High coconut cultivation is directly proportional to area under cultivation.
